# %%
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# # **Load Model**

# %%
filename = 'model_gbc.sav'
loaded_model = pickle.load(open(filename, 'rb'))

# %%
loaded_model
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('nominal_transform',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot_encoding',
#                                                                    OneHotEncoder(dtype=<class 'int'>))]),
#                                                   ['contract', 'dependents',
#                                                    'onlinesecurity',
#                                                    'onlinebackup',
#                                                    'internetservice',
#                                                    'deviceprotection',
#                                                    'techsupport',
#                                                    'paperlessbilling']),
#                                                  ('numerical_transform',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer())]),
#                                                   ['tenure',
#                                                    'monthlycharges'])])),
#                 ('balancing', RandomOverSampler(random_state=2024)),
#                 ('model',
#                  GradientBoostingClassifier(learning_rate=0.001, max_depth=1,
#                                             max_features=6, n_estimators=50,
#                                             random_state=2024))])

# %% [markdown]
# # **Dummy Observation**

# %%
new_cust = pd.DataFrame([
    {
        'dependents': 'No',
        'tenure': 23,
        'onlinesecurity': 'No',
        'onlinebackup': 'No',
        'internetservice': 'DSL',
        'deviceprotection': 'No',
        'techsupport': 'Yes',
        'contract': 'One year',
        'paperlessbilling': 'No',
        'monthlycharges': 111.90
    },
    {
        'dependents': 'Yes',
        'tenure': 9,
        'onlinesecurity': 'No',
        'onlinebackup': 'No',
        'internetservice': 'DSL',
        'deviceprotection': 'No',
        'techsupport': 'No',
        'contract': 'Month-to-month',
        'paperlessbilling': 'Yes',
        'monthlycharges': 20.15
    }
])

new_cust
# Out:
#   dependents  tenure onlinesecurity onlinebackup internetservice  \
# 0         No      23             No           No             DSL
# 1        Yes       9             No           No             DSL
#
#   deviceprotection techsupport        contract paperlessbilling  \
# 0               No         Yes        One year               No
# 1               No          No  Month-to-month              Yes
#
#    monthlycharges
# 0          111.90
# 1           20.15

# %%
# Making predictions on new_cust
predictions = loaded_model.predict(new_cust)

# Converting predictions to human-readable format ("Yes" for churn, "No" for no churn)
predictions_readable = ['Yes' if pred == 1 else 'No' for pred in predictions]

# Adding predictions to new_cust DataFrame
new_cust['Churn'] = predictions_readable

# %%
new_cust
# Out:
#   dependents  tenure onlinesecurity onlinebackup internetservice  \
# 0         No      23             No           No             DSL
# 1        Yes       9             No           No             DSL
#
#   deviceprotection techsupport        contract paperlessbilling  \
# 0               No         Yes        One year               No
# 1               No          No  Month-to-month              Yes
#
#    monthlycharges Churn
# 0          111.90    No
# 1           20.15   Yes

# %% [markdown]
# # **Predict on the Test Dataset**

# %%
x_test_preprocessed = pd.read_csv('x_test_preprocessed.csv')

# %%
def predict_churn(new_data, loaded_model):
    predictions = loaded_model.predict(new_data)
    predictions_readable = ['Yes' if pred == 1 else 'No' for pred in predictions]
    new_data['Churn'] = predictions_readable
    return new_data

# %%
new_cust_predicted = predict_churn(x_test_preprocessed, loaded_model)
new_cust_predicted
# Out:
#     dependents  tenure       onlinesecurity         onlinebackup  \
# 0           No      60                   No                  Yes
# 1           No       9                  Yes                   No
# 2           No      68                  Yes                  Yes
# 3          Yes      19                   No                   No
# 4           No       1  No internet service  No internet service
# ..         ...     ...                  ...                  ...
# 966         No      24                   No                   No
# 967        Yes      44                   No                  Yes
# 968         No      32                  Yes                   No
# 969         No      24                   No                  Yes
# 970        Yes       6                   No                  Yes
#
#     internetservice     deviceprotection          techsupport        contract  \
# 0       Fiber optic                  Yes                   No        Two year
# 1       Fiber optic                   No                   No  Month-to-month
# 2               DSL                  Yes                  Yes        Two year
# 3       Fiber optic                   No                  Yes        One year
# 4                No  No internet service  No internet service  Month-to-month
# ..              ...                  ...                  ...             ...
# 966     Fiber optic                   No                   No  Month-to-month
# 967             DSL                   No                   No        One year
# 968             DSL                   No                   No        One year
# 969     Fiber optic                  Yes                   No  Month-to-month
# 970             DSL                  Yes                  Yes        Two year
#
#     paperlessbilling  monthlycharges Churn
# 0                Yes           99.65    No
# 1                Yes           74.25   Yes
# 2                Yes           90.80    No
# 3                Yes          100.95    No
# 4                 No           20.65    No
# ..               ...             ...   ...
# 966               No           70.00   Yes
# 967              Yes           77.55    No
# 968               No           74.75    No
# 969              Yes          104.15   Yes
# 970               No           40.55    No
#
# [971 rows x 11 columns]
